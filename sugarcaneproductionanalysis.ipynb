# %% [markdown]
# # sugarcane production analysis

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df.shape
# Out:
# (103, 7)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %% [markdown]
# # data cleaning

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]= df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df = df.drop( "Unnamed: 0", axis = 1)
df.rename(columns= {"Production (Tons)": "Production(Tons)"}, inplace = True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_person(Kg)"}, inplace = True)
df.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df.shape
# Out:
# (103, 6)

# %%
df=df.dropna()

# %%
df.reset_index().drop("index", axis=1)
# Out:
#        Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0       Brazil  South America        768678382                  3668.531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                  1264.303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 99   Singapore           Asia               50                         9
# 100      Samoa        Oceania               12                         6
# 101      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg/Hectare)
# 0           10226205           75167.5
# ...

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_person(Kg)    0
# Acreage(Hectare)             0
# Yield(Kg/Hectare)            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    102 non-null    object
#  1   Continent                  102 non-null    object
#  2   Production(Tons)           102 non-null    object
#  3   Production_per_person(Kg)  102 non-null    object
#  4   Acreage(Hectare)           102 non-null    object
#  5   Yield(Kg/Hectare)          102 non-null    object
# dtypes: object(6)
# memory usage: 5.6+ KB

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_person(Kg)"] = df["Production_per_person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## univarate analysis

# %% [markdown]
# ## How many countries produce sugarcane from each continent?

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
# africa has largest countries producing sugarcane

# %% [markdown]
# ## checking outliers

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_person(Kg)"])
plt.title("Production_per_person(Kg)")
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.show()

# %%
# we have outliers in the data but outliers are required here as it shows the countries which has maximum production. And then we can
# see what are the reasons for outliers.

# %% [markdown]
# ## distrubtion of columns

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.distplot(df["Production_per_person(Kg)"])
plt.title("Production_per_person(Kg)")
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")
plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2820\1909675950.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2820\1909675950.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.violinplot(df["Production(Tons)"])

plt.title("production (tons)")
plt.subplot(2,2,2)
sns.violinplot(df["Acreage(Hectare)"])
plt.title("Average(Hectare")
plt.subplot(2,2,3)
sns.violinplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.subplot(2,2,4)
sns.violinplot(df["Production_per_person(Kg)"])
plt.title("Production_per_person(Kg)")
plt.show()

# %% [markdown]
# ## bivarate analysis

# %%
df.sample(14)
# Out:
#                      Country      Continent  Production(Tons)  \
# 80              Sierra Leone         Africa           77269.0
# 92                  Portugal         Europe            5429.0
# 73                   Somalia         Africa           21062.0
# 74                     Ghana         Africa          152136.0
# 98                   Lebanon           Asia              97.0
# 50                    Belize  North America         1457656.0
# 32                Bangladesh           Asia         4207592.0
# 84               Afghanistan           Asia           17364.0
# 7                  Australia        Oceania        34403004.0
# 57                   Senegal         Africa          696992.0
# 29        Dominican Republic  North America         4717490.0
# 76  Central African Republic         Africa          103002.0
# 2                      China           Asia       123059739.0
# 68                     Gabon         Africa          286466.0
#
# ...

# %%
df["Country"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # which country produces maximum sugarcane?

# %%
df_new=df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)_percent"] = df_new["Production(Tons)"]*100/df_new["Production(Tons)"].sum()

# %%
df_new.head()
# Out:
#           Production(Tons)  Production(Tons)_percent
# Country
# Brazil         768678382.0                 40.727285
# India          348448000.0                 18.462001
# China          123059739.0                  6.520138
# Thailand        87468496.0                  4.634389
# Pakistan        65450704.0                  3.467809

# %%
df_new["Production(Tons)_percent"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df[["Country","Production(Tons)"]].set_index("Country").sort_values("Production(Tons)",ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df.head(10)
# Out:
#                     Country      Continent  Production(Tons)  \
# 0                    Brazil  South America       768678382.0
# 1                     India           Asia       348448000.0
# 2                     China           Asia       123059739.0
# 3                  Thailand           Asia        87468496.0
# 4                  Pakistan           Asia        65450704.0
# 5                    Mexico  North America        56446821.0
# 6                  Colombia  South America        36951213.0
# 7                 Australia        Oceania        34403004.0
# 8                 Guatemala  North America        33533403.0
# 9  United States of America  North America        29926210.0
#
#    Production_per_person(Kg)  Acreage(Hectare)  Yield(Kg/Hectare)
# 0                   3668.531        10226205.0            75167.5
# 1                 260721.000         4950000.0            70393.5
# 2                  88287.000         1675215.0            73459.1
# ...

# %%
df[["Country","Production(Tons)"]].set_index("Country").head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)")

# %% [markdown]
# # which country has highest land for production?

# %%
df[["Country","Acreage(Hectare)"]].set_index("Country").sort_values("Acreage(Hectare)",ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df_acr = df.sort_values("Acreage(Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_acr,  x= "Country", y = "Acreage(Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2820\2973715568.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## which country has highest yield per hectare?

# %%
df_yield = df.sort_values("Yield(Kg/Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Yield(Kg/Hectare)",color="pink")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2820\1535958597.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## which country has highest production

# %%
df_yield = df.sort_values("Production_per_person(Kg)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Production_per_person(Kg)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2820\328127327.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## correlation

# %%
a=df[["Production(Tons)","Acreage(Hectare)","Production_per_person(Kg)","Yield(Kg/Hectare)"]].corr()

# %%
a
# Out:
#                            Production(Tons)  Acreage(Hectare)  \
# Production(Tons)                   1.000000          0.997550
# Acreage(Hectare)                   0.997550          1.000000
# Production_per_person(Kg)          0.015000          0.012557
# Yield(Kg/Hectare)                  0.132812          0.113433
#
#                            Production_per_person(Kg)  Yield(Kg/Hectare)
# Production(Tons)                            0.015000           0.132812
# Acreage(Hectare)                            0.012557           0.113433
# Production_per_person(Kg)                   1.000000           0.017999
# Yield(Kg/Hectare)                           0.017999           1.000000

# %%
sns.heatmap(a,cmap="Purples",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## do countries with largest land produces largest sugarcane?

# %%
sns.scatterplot(data=df,x="Acreage(Hectare)",y="Production(Tons)",hue="Continent")
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## do countries which yield more sugarcane per hectare produce more sugarcane in total?

# %%
sns.scatterplot(data = df, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## analysis for continent

# %%
df_continent=df.groupby("Continent").sum()

# %%
df_continent["number_of_country"]=df.groupby("Continent").count()["Country"]

# %%
df_continent.drop("Country",axis=1,inplace=True)

# %%
df_continent
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  number_of_country
# Continent
# Africa                 2142107.5                 38
# Asia                   1171871.4                 25
# Europe                  131870.9                  2
# North America          1082602.4                 22
# Oceania                 162419.1                  4
# South America           677192.7                 11

# %% [markdown]
# ## d

# %%
df_continent["Production(Tons)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## do number of countries in continent effect the sugarcane production

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_country", y= "Production(Tons)" )
plt.xticks(df_continent["number_of_country"], continent_names, rotation =90)
plt.show()

# %% [markdown]
# ## do continent with highest land produces more sugarcane

# %%
sns.lineplot(data=df_continent,x="Acreage(Hectare)",y="Production(Tons)")
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## production distribution by continent

# %%
df_continent["Production(Tons)"].plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='Production(Tons)'>

# %%
df_continent.corr()
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# number_of_country                  0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# number_of_country                  0.132817           0.989712
#
#                            number_of_country
# Production(Tons)                    0.109244
# Production_per_person(Kg)           0.540086
# ...
